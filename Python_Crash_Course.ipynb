# %% [markdown]
# # **Python Crash Course**
#
# Before you begin, click ![image.png](data:image/png;base64,...) on th top right.
#
# * Uncheck all checks in AI assistance
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Arithmetic operation**
#
# * Hit the run code button to see the output of `print(1 / 2)`.
# * You can run by clicking the triangle or press `shift+enter`

# %%
# Comment line after "#"
print(1 / 2)
# Out:
# 0.5

# %% [markdown]
# * Now, print the sum of 1 and 2

# %% [markdown]
# * Figure out how to perfrom arithmetic of
#   * $1 + 2$
#   * $1 - 2$
#   * $1 \times 2$
#   * $\dfrac{1}{2}$

# %% [markdown]
# * Look up google or ask AI how you can find a remainder of a division in Python.  E.g., the remainder of 18 divided by 7 is 4.

# %% [markdown]
# * Find out how you can do exponentiation of $5^2$

# %% [markdown]
# * If your principal is $100$ and the interest rate is $10\%$, how much would this be after 5 years?

# %% [markdown]
# # **Variable**
#
# * Use to store values

# %% [markdown]
# ### **Calculate future value**
#
# * Let `Principal` = 100
# * Let `Interest` = 0.1
# * Let `Year` = 5
#
# Redo the previous calculation using exactly the same variables' names.

# %% [markdown]
# * If the interest rate changes to 5%, how would you redo the calculation?

# %% [markdown]
# ### **Type**
#
# * Check the type of the variables above by typing `type(variable_name)`, e.g.,
#
# ```
# type(Year)
# ```

# %% [markdown]
# * What are the types of
#
#   * 'Python' (รวมตัวเครื่องหมายคำพูด)
#   * True

# %% [markdown]
# * Find out what happens when you do
#
# * `2 + 5`, and
# * `'ab' + 'cd'` (รวมตัวเครื่องหมายคำพูด), and
# * `'2' + '5'` (รวมตัวเครื่องหมายคำพูด)

# %% [markdown]
# * What about
#
#   * $2 \times 5$
#   * `'2'*5`

# %% [markdown]
# ### **Exercise 1**
#
# * Define `savings` and `new_savings` equal `100` and `40` respectively.
# * Add `savings` and `new_savings` and assign it to `total_savings`.
# Use type() to print the resulting type of `total_savings`.
# * Print the value of `total_savings`
# * Print the **`type`** of `total_savings`

# %% [markdown]
# # **Python Lists**
#
# * Store multiple values in the bracket
# * Can have any type of values in the same list

# %% [markdown]
# ### **Exercise 2**
#
# * Create a list containing
#
#   * `height` (Enter your height)
#   * `weight` (Enter yours)
#   * `'bmi'` $\left(BMI = \dfrac{weight}{height^2}\right)$

# %% [markdown]
# * Create a list of list where
#
# ```
# You = [['Height', height],
#        ['Weight', weight],
#        ['BMI', bmi]]
#
# ```

# %% [markdown]
# ## **Indexing**
#
# * Create a list of the number from one to five and assign it to a variable called `my_list`.
# * Print    `my_list[2]`
# * Figure out how to extract the number `1` from `my_list`
# * What does `my_list[-1]` correspond to?

# %% [markdown]
# ## **Slicing**
#
# ![image.png](data:image/png;base64,...)
#
# * Try `my_list[1:3]`

# %% [markdown]
# * Try `my_list[0:3]`

# %% [markdown]
# * Try `my_list[ :3]`

# %% [markdown]
# * Try `my_list[:]`

# %% [markdown]
# * Try `my_list[0:5:1]`

# %% [markdown]
# * Try `my_list[0:5:2]`

# %% [markdown]
# * Try * Try `my_list[::-1]`

# %% [markdown]
# ### **Subsetting lists of lists**
#
# Given a list
#
# ```
# house = [["hallway", 11.25],
#          ["kitchen", 18.0],
#          ["living room", 20.0],
#          ["bedroom", 10.75],
#          ["bathroom", 9.50]]
# ```
# Indexing the list to get 11.25

# %% [markdown]
# ## **Changing list elements**
#
# From your ` my_list`, change your `height` to be anything you want, BY list INDEXING.

# %% [markdown]
# Try executing the below cell

# %%
A = [1, 2, 3, 4, 5, 6]
A + 99

# %%
# Again
A = [1, 2, 3, 4, 5, 6]
A + [99]

# %%
# Again
A = [1, 2, 3, 4, 5, 6]
A.extend([99])

# %%
# And again
A = [1, 2, 3, 4, 5, 6]
A.append(99)

# %% [markdown]
# ## **Delete list element**
#
# Find out what happen to
#
# ```
# x = ["a", "b", "c", "d"]
# del x[1]
# ```

# %% [markdown]
# ### **Exercise 3**
#
# Given the list
# ```
# areas = ["hallway", 11.25, "kitchen", 18.0,
#         "chill zone", 20.0, "bedroom", 10.75,
#          "bathroom", 10.50, "poolhouse", 24.5,
#          "garage", 15.45]
#
# ```
#
# Delete "poolhouse" and 24.5.

# %% [markdown]
# ## **List pitfall**

# %%
x = ['a', 'b', 'c']
y = x
y[0] = 999

# %% [markdown]
# What should be your `x`?  Find it.

# %% [markdown]
# To avoid this,

# %%
x = [1, 2, 3]
y = x.copy() #There are many ways to do this
y[0] = 9999

# %% [markdown]
# # **Functions**
#
# You saw **`type`** and **`print`**

# %%
# Try guessing a way to use an existing function to find the maximum of the following list
nums = [3, 1, 5, 9 , 7]

# %% [markdown]
# A **`round`** function can round decimal.  E.g., `round(1.68, 1) = 1.7`
# Figure out how to round 1.68 to 2.0

# %%
# Out:
# 2.0

# %% [markdown]
# Try using **`help(round)`**

# %% [markdown]
# There are also functions like **`str()`**, **`int()`**, **`bool()`** and **`float()`** to switch between data types. You can find out about them [here](https://docs.python.org/3/library/functions.html).
#
# ### **Exercise 4**
#
# * Use **`print()`** in combination with **`type()`** to print out the type of `var1 = [1, 3, '5']`.
# * Use **`len()`** to get the length of the list `var1`. Wrap it in a **`print()`** call to directly print it out.
# * Use **`int()`** to convert `var2 = True` to an integer. Then print it out.
# * Use **`help()`** to look up the documentation of **`sorted`**, and print `var1` in <u>*descending*</u> order.
# * What happens when you run **`max(var1)`**?

# %% [markdown]
# # **Methods**
#
# Functions associated with Python objects
#
# * You do not need to memorize them.  Just only frequently used fews.

# %% [markdown]
# ## **List methods**

# %%
var1 = [11, 33, 55, 77, 99, 99, 99, 33, 33, 11]
print(var1.index(55))
print(var1.count(33))

# %% [markdown]
# ## **String methods**

# %%
'putain'.capitalize()

# %% [markdown]
# * Use the str method called **`upper()`** to make `'putain'` uppercase letter.

# %%
'putain'.replace('ain', 'rid')

# %% [markdown]
# Some objects have similar methods' names.

# %%
var1 = [11, 33, 55, 77, 99, 99, 99, 33, 33, 11]
print(var1.index(55))

print('putain'.index('n'))

# %% [markdown]
# Some methods do not exist in another object.

# %%
var1 = [11, 33, 55, 77, 99, 99, 99, 33, 33, 11]
var1.replace(33,111)

# %% [markdown]
# You saw list methods **`append`** and **`extend`**.  Let's recall them.
#
# * Given `x = [1, 3, 5, 7]`, append `999` to the last position of this list.
# * Concatenate `y = ['one', 'two', 'three']` to `x` using **`extend`**.

# %% [markdown]
# ### **Exercise 5 Str Methods**
#
# * Use the **`.upper()`** method on `x` and store the result in `y`.
#
# * Print out `x` and `y`. Did both change?
# * Print out the number of `o`'s on the variable place by calling **`.count()`** on `x` and passing the letter `'o'` as an input to the method.

# %%
x = "Python"
y =

# %% [markdown]
# ### **Exercise 6 List Methods**
#
# * Use the **`.index()`** method to get the index of the element in `array` that is equal to `20.0`. Print out this index.
#
# * Call **`.count()`** on `array` to find out how many times `9.50` appears in the list. Print out this number.
#
# * Use **`.append()`** twice to add  `24.5` and `15.45`, respectively to `array`. Make sure to add them in this order.
# (Those who want to refresh writing **`for`** loop may feel adventurous.)
#
# * Print out `array`.
#
# * Use the **`.reverse()`** method to reverse the order of the elements in array.
#
# * Print out `array` once more.

# %%
areas = [11.25, 18.0, 20.0, 10.75, 9.50]

# %% [markdown]
# # **Packages**
#
# You need to import lots of packages in Python.  For example, how would you calculate the squar root of 3?

# %% [markdown]
# There are many ways to import.

# %% [markdown]
# # **Numpy**
#
# Suppose you have a list of prices, called `prices`, and a list of quantities, called `quants`.  Is there any simple way to get the total expenditure?
#
# * $P_1 = 2, P_2 = 3$
# * $x_1 = 5, x_2 = 5$

# %%
prices = [2, 3]
quants = [5, 5]
prices * quants

# %% [markdown]
# You can do it using **`for`** loop, and any who wants to brush up this knowledge should do so now.

# %%
import numpy as np

# Using np.array on prices and quants
# Out:
# np.int64(25)

# %% [markdown]
# * Given a list of `[1, 2, 3, 4, 5]`, find the squares of all numbers in this list.

# %% [markdown]
# ## **Numpy subsetting**
#
# Suppose we want to filter the number from a list which is greater than 3.
#
#
#
# ```
# x = [1, 2, 3, 4, 5, 6]
# ```

# %%
x = [1, 2, 3, 4, 5, 6]
y = np.array([x])
y[y > 3]

# %% [markdown]
# ### **Exercise 7**
#
# * Try using numpy subsetting to choose only the even numbers from the list `x = [1, 2, 3, 4, 5, 6]`

# %% [markdown]
# ### **Exercise 8**
#
# * Given prices = [1, 2, 3, 4] in dollars, convert this into Thai baht.

# %% [markdown]
# ## **Indexing and slicing**
#
# * Pick out the 5th index of the list `x = [1, 2, 3, 4, 5, 6]`
# * Choose element 1 to 3

# %% [markdown]
# # **Numpy 2D array** (Actually there can be up to n-dimensional array)
#
# * Can be created from list of list.
# * Like a 2 dimensional matrix

# %%
import numpy as np

prices = np.array([2, 3, 4, 5])
quants = np.array([5, 5, 6, 7])

data = np.array([[2, 3, 4, 5],  # must have comma
                 [5, 5, 6, 7]])

data.shape #attribute, not method

# %% [markdown]
# ## **Indexing 2D array**
#
# * Try getting number 4 from `data` array.  (There are 2 syntaxes to do this.)

# %% [markdown]
# ## **Slicing 2D array**
#
# * `data[:, :]` ?
# * `data[:, 1:3]`?
# * `data[0, :]` ?

# %% [markdown]
# # **Numpy Stats**
#
# * np.mean
# * np.median
# * np.std
# ... and a lot more
